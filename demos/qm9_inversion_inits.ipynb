# %%
"""
Bispectrum Inversion for Molecular Environments - Optimized for Apple M2 Pro
"""
import os
import time
import pickle

import numpy as np
import jax
import jax.numpy as jnp
import optax
import matplotlib.pyplot as plt
from tqdm import tqdm
import sys
from functools import partial
import math

# Add src directory to path
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
src_dir = os.path.join(project_root, 'src')
sys.path.append(src_dir)

from spectra import sum_of_diracs, bispectrum

#------------------------------------------------------------------------------
# JAX & Hardware Configuration
#------------------------------------------------------------------------------

jax.config.update('jax_enable_x64', True)
jax.config.update('jax_platform_name', 'gpu')
jax.config.update('jax_default_matmul_precision', 'high')
os.environ['XLA_PYTHON_CLIENT_MEM_FRACTION'] = '0.85'

#------------------------------------------------------------------------------
# Constants
#------------------------------------------------------------------------------

LMAX = 4
MAX_ENV_SIZE = 5

#------------------------------------------------------------------------------
# Helpers
#------------------------------------------------------------------------------

def determine_optimal_batch_size() -> int:
    """Pick a default batch size: 8 on M1/M2 silicon, else 5."""
    try:
        import platform
        return 8 if platform.processor() == 'arm' else 5
    except:
        return 5

@partial(jax.jit, static_argnames=('max_size',))
def pad_environment(env, max_size=MAX_ENV_SIZE):
    """
    Take an (N×3) array (N may be <, =, or > max_size),
    pad it with zeros so it has at least (max_size) rows,
    then slice to exactly (max_size×3).
    """
    env = jnp.array(env, dtype=jnp.float64)             # (N,3)
    # Pad below with max_size zeros → shape = (N+max_size, 3)
    padded = jnp.pad(env, ((0, max_size), (0, 0)))
    # Then take the first max_size rows: shape = (max_size, 3)
    return padded[:max_size]

@jax.jit
def compute_bispectrum_for(env):
    """Compute bispectrum for an (M×3) array, zeros allowed."""
    return bispectrum(sum_of_diracs(env, LMAX))

@partial(jax.jit, static_argnums=(2,))
def invert_with_adam(true_bs, init_pts, num_iters=2000):
    """Adam-based inversion."""
    lr = 1e-2
    opt = optax.adam(lr)
    state = opt.init(init_pts)
    def loss_fn(x):
        pred_bs = bispectrum(sum_of_diracs(x, LMAX))
        return jnp.mean(jnp.abs(true_bs - pred_bs))
    def step(carry, _):
        pts, st = carry
        g = jax.grad(loss_fn)(pts)
        updates, st = opt.update(g, st, pts)
        return (optax.apply_updates(pts, updates), st), None
    (final_pts, _), _ = jax.lax.scan(step, (init_pts, state), None, length=num_iters)
    return final_pts

@partial(jax.jit, static_argnums=(2,))
def invert_with_adam_history(true_bs, init_pts, num_iters=2000):
    """Adam-based inversion (returns history)."""
    lr = 1e-2
    opt = optax.adam(lr)
    state = opt.init(init_pts)
    def loss_fn(x):
        pred_bs = bispectrum(sum_of_diracs(x, LMAX))
        return jnp.mean(jnp.abs(true_bs - pred_bs))
    def scan_step(carry, i):
        pts, st, hist = carry
        g = jax.grad(loss_fn)(pts)
        updates, st = opt.update(g, st, pts)
        pts = optax.apply_updates(pts, updates)
        hist = hist.at[i].set(pts)
        return (pts, st, hist), None

    hist0 = jnp.broadcast_to(init_pts, (num_iters, *init_pts.shape))
    ( _, _, history ), _ = jax.lax.scan(scan_step, (init_pts, state, hist0), jnp.arange(num_iters))
    return history

@partial(jax.jit, static_argnames=('num_starts',))
def find_best_initial(true_bs, rng, num_starts: int = 5):
    """
    1) Draw `num_starts` different inits in one batch
    2) Run invert_with_adam on all of them in parallel via vmap
    3) Compute the final bispectrum-loss of each
    4) Return the best-final-pts
    """
    # split rng → (num_starts,) keys
    keys = jax.random.split(rng, num_starts)

    # batch of inits: (num_starts, 10,3)
    init_batch = jax.vmap(lambda k: jax.random.normal(k, (20,3), jnp.float64))(keys)

    # run all starts in parallel: (num_starts, 10,3)
    finals = jax.vmap(lambda init: invert_with_adam(true_bs, init))(init_batch)

    # compute loss for each final
    def loss_of(pts):
        pred_bs = bispectrum(sum_of_diracs(pts, LMAX))
        return jnp.mean(jnp.abs(true_bs - pred_bs))
    losses = jax.vmap(loss_of)(finals)  # (num_starts,)

    # pick best
    best_idx = jnp.argmin(losses)
    return finals[best_idx]

def stack_points_jittable(points: np.ndarray) -> jnp.ndarray:
    """
    Cluster points by alignment (cosine > 0.866), sum and threshold
    with half the max norm. Returns (K×3) JAX array or empty.
    """
    norms = np.linalg.norm(points, axis=1, keepdims=True)
    valid = norms[:,0] > 0
    pts = points.copy()
    pts[valid] /= norms[valid]
    D = pts @ pts.T
    used = np.ones(len(points),bool)
    clusters = []
    while used.any():
        i = np.argmax(used)
        aligned = (D[i] > 0.866) & used
        if not aligned.any(): break
        clusters.append(points[aligned].sum(0))
        used[aligned] = False
    if not clusters:
        return jnp.zeros((0,3), jnp.float64)
    C = np.stack(clusters)
    norms = np.linalg.norm(C, axis=1)
    thresh = 0.5 * norms.max()
    C = C[norms >= thresh]
    return jnp.array(C, jnp.float64)

def radius_mae_fast(a1: np.ndarray, a2: np.ndarray) -> float:
    """MAE of sorted non-zero radii; returns 0.0 if both empty."""
    r1 = np.linalg.norm(a1, axis=1); r2 = np.linalg.norm(a2, axis=1)
    r1, r2 = np.sort(r1[r1>1e-10]), np.sort(r2[r2>1e-10])
    if len(r1)==0 and len(r2)==0: return 0.0
    if len(r1)!=len(r2): return np.nan
    return float(np.mean(np.abs(r1 - r2)))

#------------------------------------------------------------------------------
# Main Pipeline
#------------------------------------------------------------------------------

def process_environments(envs, num_to_use=20, batch_size=None, scale=1, num_starts=5):
    if num_to_use and num_to_use < len(envs):
        envs = envs[:num_to_use]
    batch_size = batch_size or determine_optimal_batch_size()
    start = time.time()

    padded = [scale * pad_environment(e) for e in envs]
    targets = [compute_bispectrum_for(e) for e in padded]

    all_maes = []
    master_rng = jax.random.PRNGKey(0)

    for idx, (true_bs, geom) in enumerate(zip(targets, padded)):
        try:
            # split RNG for this env
            master_rng, subkey = jax.random.split(master_rng)

            # 1) find best final-pts across `num_starts` in one vmap
            best_pred = find_best_initial(true_bs, subkey, num_starts)

            # 2) cluster that best prediction
            pred_np = np.array(best_pred)
            stacked = stack_points_jittable(pred_np)

            print(type(stacked))
            print(stacked.shape)
            print(stacked)

            # 3) run full history only once
            if stacked.shape[0]:
                hist = invert_with_adam_history(true_bs, stacked, num_iters=2000)
                hist_np = np.array(hist)
                geom_np = np.array(geom)
                maes = [radius_mae_fast(h, geom_np) / scale for h in hist_np]
            else:
                maes = [np.nan]*2500

        except Exception:
            maes = [np.nan]*2500

        all_maes.append(maes)
        if idx % batch_size == 0:
            jax.clear_caches()

    elapsed = time.time() - start
    all_maes = np.array(all_maes)
    nan_counts = sum(1 for row in all_maes if np.isnan(row).any())
    print(f"Total rows with NaN values: {nan_counts} out of {len(all_maes)}")
    avg = np.nanmean(all_maes, axis=0)
    print(f"Done in {elapsed:.1f}s ({elapsed/len(envs):.2f}s/env)")

    return {
        "all_mae_values": all_maes,
        "avg_mae": avg,
        "processing_time": elapsed,
        "num_envs": len(envs)
    }

def save_and_plot_results(res, out_dir="../results"):
    os.makedirs(out_dir, exist_ok=True)
    n = res["num_envs"]
    fname = f"{out_dir}/mae_{n}_envs.pkl"
    with open(fname, "wb") as f:
        pickle.dump(res, f)
    print(f"Results saved to {fname}")

    plt.figure(figsize=(12,8))
    iters = np.arange(len(res["avg_mae"]))
    plt.plot(iters, res["avg_mae"], marker='o', linewidth=3, label="Adam avg")
    for row in res["all_mae_values"]:
        plt.plot(iters, row, alpha=0.2)
    # plt.yscale('log')
    plt.xlabel("Iteration")
    plt.ylabel("MAE")
    plt.title(f"MAE over iterations ({n} envs)")
    plt.grid(alpha=0.3)
    plt.legend()
    plt.tight_layout()

    png = f"{out_dir}/mae_{n}_envs.png"
    plt.savefig(png, dpi=300)
    print(f"Plot saved to {png}")
    return plt

def main():
    print("Loading data…")
    with open('../data/qm9_local_envs_10000.pkl','rb') as f:
        envs = pickle.load(f)
    print(f"{len(envs)} environments loaded")

    # Warm up JIT
    _ = compute_bispectrum_for(jnp.zeros((3,3)))

    results = process_environments(envs, num_to_use=20, num_starts=1)
    plt = save_and_plot_results(results)
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# Loading data…
# 10000 environments loaded
# <class 'jaxlib.xla_extension.ArrayImpl'>
# (4, 3)
# [[ 0.47287355 -0.75484817  0.62192524]
#  [ 0.74319498  0.70865373 -0.34302388]
#  [-0.4571254  -0.47110308 -0.86229375]
#  [-0.76285697  0.51906424  0.57374284]]
# <class 'jaxlib.xla_extension.ArrayImpl'>
# (3, 3)
# [[-0.18631185 -0.05241947 -1.00149342]
#  [-0.86984134  0.29015877  0.42886556]
#  [ 0.63265875  0.80921953  0.11749699]]
# <class 'jaxlib.xla_extension.ArrayImpl'>
# (2, 3)
# [[-0.31816793  0.07164202  0.89152841]
#  [ 0.9454888   0.16346996  0.05273048]]
# ---------------------------------------------------------------------------
# JaxStackTraceBeforeTransformation         Traceback (most recent call last)
# File ~/.local/share/uv/python/cpython-3.10.16-macos-aarch64-none/lib/python3.10/runpy.py:196, in _run_module_as_main()
#     195     sys.argv[0] = mod_spec.origin
# --> 196 return _run_code(code, main_globals, None,
#     197                  "__main__", mod_spec)
#
# File ~/.local/share/uv/python/cpython-3.10.16-macos-aarch64-none/lib/python3.10/runpy.py:86, in _run_code()
#      79 run_globals.update(__name__ = mod_name,
#      80                    __file__ = fname,
#      81                    __cached__ = cached,
#    (...)
#      84                    __package__ = pkg_name,
#      85                    __spec__ = mod_spec)
# ---> 86 exec(code, run_globals)
#      87 return run_globals
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/ipykernel_launcher.py:18
#      16 from ipykernel import kernelapp as app
# ---> 18 app.launch_new_instance()
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/traitlets/config/application.py:1075, in launch_instance()
#    1074 app.initialize(argv)
# -> 1075 app.start()
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/ipykernel/kernelapp.py:739, in start()
#     738 try:
# --> 739     self.io_loop.start()
#     740 except KeyboardInterrupt:
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/tornado/platform/asyncio.py:205, in start()
#     204 def start(self) -> None:
# --> 205     self.asyncio_loop.run_forever()
#
# File ~/.local/share/uv/python/cpython-3.10.16-macos-aarch64-none/lib/python3.10/asyncio/base_events.py:603, in run_forever()
#     602 while True:
# --> 603     self._run_once()
#     604     if self._stopping:
#
# File ~/.local/share/uv/python/cpython-3.10.16-macos-aarch64-none/lib/python3.10/asyncio/base_events.py:1909, in _run_once()
#    1908     else:
# -> 1909         handle._run()
#    1910 handle = None
#
# File ~/.local/share/uv/python/cpython-3.10.16-macos-aarch64-none/lib/python3.10/asyncio/events.py:80, in _run()
#      79 try:
# ---> 80     self._context.run(self._callback, *self._args)
#      81 except (SystemExit, KeyboardInterrupt):
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py:545, in dispatch_queue()
#     544 try:
# --> 545     await self.process_one()
#     546 except Exception:
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py:534, in process_one()
#     533         return
# --> 534 await dispatch(*args)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py:437, in dispatch_shell()
#     436     if inspect.isawaitable(result):
# --> 437         await result
#     438 except Exception:
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/ipykernel/ipkernel.py:362, in execute_request()
#     361 self._associate_new_top_level_threads_with(parent_header)
# --> 362 await super().execute_request(stream, ident, parent)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py:778, in execute_request()
#     777 if inspect.isawaitable(reply_content):
# --> 778     reply_content = await reply_content
#     780 # Flush output before sending the reply.
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/ipykernel/ipkernel.py:449, in do_execute()
#     448 if accepts_params["cell_id"]:
# --> 449     res = shell.run_cell(
#     450         code,
#     451         store_history=store_history,
#     452         silent=silent,
#     453         cell_id=cell_id,
#     454     )
#     455 else:
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/ipykernel/zmqshell.py:549, in run_cell()
#     548 self._last_traceback = None
# --> 549 return super().run_cell(*args, **kwargs)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3077, in run_cell()
#    3076 try:
# -> 3077     result = self._run_cell(
#    3078         raw_cell, store_history, silent, shell_futures, cell_id
#    3079     )
#    3080 finally:
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3132, in _run_cell()
#    3131 try:
# -> 3132     result = runner(coro)
#    3133 except BaseException as e:
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/IPython/core/async_helpers.py:128, in _pseudo_sync_runner()
#     127 try:
# --> 128     coro.send(None)
#     129 except StopIteration as exc:
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3336, in run_cell_async()
#    3333 interactivity = "none" if silent else self.ast_node_interactivity
# -> 3336 has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    3337        interactivity=interactivity, compiler=compiler, result=result)
#    3339 self.last_execution_succeeded = not has_raised
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3519, in run_ast_nodes()
#    3518     asy = compare(code)
# -> 3519 if await self.run_code(code, result, async_=asy):
#    3520     return True
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3579, in run_code()
#    3578     else:
# -> 3579         exec(code_obj, self.user_global_ns, self.user_ns)
#    3580 finally:
#    3581     # Reset our crash handler in place
#
# Cell In[33], line 272
#     271 if __name__ == "__main__":
# --> 272     main()
#
# Cell In[33], line 267, in main()
#     265 _ = compute_bispectrum_for(jnp.zeros((3,3)))
# --> 267 results = process_environments(envs, num_to_use=20, num_starts=1)
#     268 plt = save_and_plot_results(results)
#
# Cell In[33], line 204, in process_environments()
#     203 if stacked.shape[0]:
# --> 204     hist = invert_with_adam_history(true_bs, stacked, num_iters=2000)
#     205     hist_np = np.array(hist)
#
# Cell In[33], line 106, in invert_with_adam_history()
#     105 hist0 = jnp.broadcast_to(init_pts, (num_iters, *init_pts.shape))
# --> 106 ( _, _, history ), _ = jax.lax.scan(scan_step, (init_pts, state, hist0), jnp.arange(num_iters))
#     107 return history
#
# Cell In[33], line 99, in scan_step()
#      98 pts, st, hist = carry
# ---> 99 g = jax.grad(loss_fn)(pts)
#     100 updates, st = opt.update(g, st, pts)
#
# Cell In[33], line 95, in loss_fn()
#      94 def loss_fn(x):
# ---> 95     pred_bs = bispectrum(sum_of_diracs(x, LMAX))
#      96     return jnp.mean(jnp.abs(true_bs - pred_bs))
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/src/spectra.py:34, in sum_of_diracs()
#      33     values = jnp.linalg.norm(vectors, axis=1)
# ---> 34 return e3nn.sum(e3nn.s2_dirac(vectors, lmax, p_val=1, p_arg=-1) * values[:, None], axis=0)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/e3nn_jax/_src/s2grid.py:772, in s2_dirac()
#     771 irreps = s2_irreps(lmax, p_val, p_arg)
# --> 772 coeffs = e3nn.spherical_harmonics(
#     773     irreps, position, normalize=True, normalization="integral"
#     774 )  # [dim]
#     775 return coeffs / jnp.sqrt(4 * jnp.pi)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/e3nn_jax/_src/spherical_harmonics/__init__.py:168, in spherical_harmonics()
#     166     x = x / jnp.sqrt(r2)
# --> 168 sh = _jited_spherical_harmonics(
#     169     tuple(ir.l for _, ir in irreps_out), x, normalization, algorithm
#     170 )
#     171 sh = [
#     172     jnp.repeat(y[..., None, :], mul, -2) if mul != 1 else y[..., None, :]
#     173     for (mul, ir), y in zip(irreps_out, sh)
#     174 ]
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/e3nn_jax/_src/spherical_harmonics/__init__.py:183, in _jited_spherical_harmonics()
#     182 if "custom_jvp" in algorithm:
# --> 183     return _custom_jvp_spherical_harmonics(ls, x, normalization, algorithm)
#     184 else:
#
# JaxStackTraceBeforeTransformation: KeyboardInterrupt
#
# The preceding stack trace is the source of the JAX operation that, once transformed by JAX, triggered the following exception.
#
# --------------------
#
# The above exception was the direct cause of the following exception:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 272
#     269     plt.show()
#     271 if __name__ == "__main__":
# --> 272     main()
#
# Cell In[33], line 267, in main()
#     264 # Warm up JIT
#     265 _ = compute_bispectrum_for(jnp.zeros((3,3)))
# --> 267 results = process_environments(envs, num_to_use=20, num_starts=1)
#     268 plt = save_and_plot_results(results)
#     269 plt.show()
#
# Cell In[33], line 204, in process_environments(envs, num_to_use, batch_size, scale, num_starts)
#     202 # 3) run full history only once
#     203 if stacked.shape[0]:
# --> 204     hist = invert_with_adam_history(true_bs, stacked, num_iters=2000)
#     205     hist_np = np.array(hist)
#     206     geom_np = np.array(geom)
#
#     [... skipping hidden 1 frame]
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/pjit.py:340, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     335 if config.no_tracing.value:
#     336   raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     337                      "`jit`, but 'no_tracing' is set")
#     339 (outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked, executable,
# --> 340  pgle_profiler) = _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     342 maybe_fastpath_data = _get_fastpath_data(
#     343     executable, out_tree, args_flat, out_flat, attrs_tracked, jaxpr.effects,
#     344     jaxpr.consts, jit_info.abstracted_axes,
#     345     pgle_profiler)
#     347 return outs, maybe_fastpath_data, _need_to_rebuild_with_fdo(pgle_profiler)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/pjit.py:178, in _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     177 def _python_pjit_helper(fun: Callable, jit_info: PjitInfo, *args, **kwargs):
# --> 178   p, args_flat = _infer_params(fun, jit_info, args, kwargs)
#     180   for arg in args_flat:
#     181     dispatch.check_arg(arg)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/pjit.py:716, in _infer_params(fun, ji, args, kwargs)
#     713   with (_internal_use_concrete_mesh(phys_mesh),
#     714         mesh_lib.use_abstract_mesh(phys_mesh.abstract_mesh)):
#     715     return _infer_params_internal(fun, ji, args, kwargs)
# --> 716 return _infer_params_internal(fun, ji, args, kwargs)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/pjit.py:739, in _infer_params_internal(fun, ji, args, kwargs)
#     736 entry = _infer_params_cached(fun, ji, signature, avals, ctx_mesh)
#     738 if entry.pjit_params is None:
# --> 739   p, args_flat = _infer_params_impl(
#     740       fun, ji, ctx_mesh, dbg, args, kwargs, in_avals=avals)
#     741   if p.attrs_tracked:  # if attrs, don't populate the cache
#     742     return p, p.consts + args_flat
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/pjit.py:636, in _infer_params_impl(***failed resolving arguments***)
#     629 in_shardings_flat, in_layouts_flat = _process_in_axis_resources(
#     630     in_shardings_treedef, in_shardings_leaves,
#     631     ji.in_layouts_treedef, ji.in_layouts_leaves,
#     632     in_avals, in_tree, flat_fun.debug_info, device_or_backend_set, have_kwargs)
#     634 attr_token = _attr_cache_index(flat_fun, in_type)
# --> 636 jaxpr, consts, out_avals, attrs_tracked = _create_pjit_jaxpr(
#     637     flat_fun, in_type, attr_token, IgnoreKey(ji.inline))
#     639 if config.mutable_array_checks.value:
#     640   _check_no_aliased_closed_over_refs(dbg, (*jaxpr.consts, *consts), explicit_args)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/linear_util.py:477, in cache.<locals>.memoized_fun(fun, *args)
#     475 if do_explain := explain and config.explain_cache_misses.value:
#     476   start = time.time()
# --> 477 ans = call(fun, *args)
#     478 if do_explain:
#     479   explain(fun, cache is new_cache, cache, key, time.time() - start)  # type: ignore
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/pjit.py:1441, in _create_pjit_jaxpr(***failed resolving arguments***)
#    1439     attrs_tracked = []
#    1440   else:
# -> 1441     jaxpr, global_out_avals, consts, attrs_tracked = pe.trace_to_jaxpr_dynamic(
#    1442         fun, in_type)
#    1443     # assert attr_data is sentinel or attr_data matches attrs_tracked
#    1445 if config.debug_key_reuse.value:
#    1446   # Import here to avoid circular imports
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/profiler.py:334, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     331 @wraps(func)
#     332 def wrapper(*args, **kwargs):
#     333   with TraceAnnotation(name, **decorator_kwargs):
# --> 334     return func(*args, **kwargs)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:2223, in trace_to_jaxpr_dynamic(fun, in_avals, keep_inputs)
#    2221 try:
#    2222   with core.set_current_trace(trace):
# -> 2223     ans = fun.call_wrapped(*in_tracers)
#    2225   out_tracers = map(trace.to_jaxpr_tracer, ans)
#    2226   _check_no_returned_refs(fun.debug_info, out_tracers)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/linear_util.py:211, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     209 def call_wrapped(self, *args, **kwargs):
#     210   """Calls the transformed function"""
# --> 211   return self.f_transformed(*args, **kwargs)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/api_util.py:288, in _argnums_partial(_fun, _dyn_argnums, _fixed_args, *dyn_args, **kwargs)
#     286 args = [next(fixed_args_).val if x is sentinel else x for x in args]
#     287 assert next(fixed_args_, sentinel) is sentinel
# --> 288 return _fun(*args, **kwargs)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/api_util.py:73, in flatten_fun(f, store, in_tree, *args_flat)
#      69 @lu.transformation_with_aux2
#      70 def flatten_fun(f: Callable, store: lu.Store,
#      71                 in_tree: PyTreeDef, *args_flat):
#      72   py_args, py_kwargs = tree_unflatten(in_tree, args_flat)
# ---> 73   ans = f(*py_args, **py_kwargs)
#      74   ans, out_tree = tree_flatten(ans)
#      75   store.store(out_tree)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/api_util.py:314, in _argnames_partial(_fun, _fixed_kwargs, *args, **dyn_kwargs)
#     311 @lu.transformation2
#     312 def _argnames_partial(_fun, _fixed_kwargs: WrapKwArgs, *args, **dyn_kwargs):
#     313   kwargs = dict({k: v.val for k, v in _fixed_kwargs.val.items()}, **dyn_kwargs)
# --> 314   return _fun(*args, **kwargs)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/api_util.py:288, in _argnums_partial(_fun, _dyn_argnums, _fixed_args, *dyn_args, **kwargs)
#     286 args = [next(fixed_args_).val if x is sentinel else x for x in args]
#     287 assert next(fixed_args_, sentinel) is sentinel
# --> 288 return _fun(*args, **kwargs)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/linear_util.py:402, in _get_result_paths_thunk(_fun, _store, *args, **kwargs)
#     400 @transformation_with_aux2
#     401 def _get_result_paths_thunk(_fun: Callable, _store: Store, *args, **kwargs):
# --> 402   ans = _fun(*args, **kwargs)
#     403   result_paths = tuple(f"result{_clean_keystr_arg_names(path)}" for path, _ in generate_key_paths(ans))
#     404   if _store:
#     405     # In some instances a lu.WrappedFun is called multiple times, e.g.,
#     406     # the bwd function in a custom_vjp
#
# Cell In[33], line 106, in invert_with_adam_history(true_bs, init_pts, num_iters)
#     103     return (pts, st, hist), None
#     105 hist0 = jnp.broadcast_to(init_pts, (num_iters, *init_pts.shape))
# --> 106 ( _, _, history ), _ = jax.lax.scan(scan_step, (init_pts, state, hist0), jnp.arange(num_iters))
#     107 return history
#
#     [... skipping hidden 1 frame]
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/lax/control_flow/loops.py:308, in scan(f, init, xs, length, reverse, unroll, _split_transpose)
#     300   return (init_flat, carry_avals, carry_avals_out, init_tree, in_flat, jaxpr,
#     301           consts, out_tree, out_tree_children, attrs_tracked)
#     303 # The carry input and output avals must match exactly. However, we want to account for
#     304 # the case when init contains weakly-typed values (e.g. Python scalars), with avals that
#     305 # may not match the output despite being compatible by virtue of their weak type.
#     306 # To do this, we compute the jaxpr in two passes: first with the raw inputs, and if
#     307 # necessary, a second time with modified init values.
# --> 308 init_flat, carry_avals, carry_avals_out, init_tree, *rest = _create_jaxpr(init)
#     309 new_init_flat, changed = _promote_weak_typed_inputs(init_flat, carry_avals, carry_avals_out)
#     310 if changed:
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/lax/control_flow/loops.py:281, in scan.<locals>._create_jaxpr(init)
#     279 in_flat, in_tree = tree_flatten((init, xs))
#     280 carry_avals = tuple(_map(core.get_aval, init_flat))
# --> 281 jaxpr, consts, out_tree, attrs_tracked = _initial_style_jaxpr_attrs(
#     282     f, in_tree, (*carry_avals, *x_avals), debug_info=dbg_body)
#     283 if config.mutable_array_checks.value:
#     284   _check_no_aliased_closed_over_refs(dbg_body, (*jaxpr.consts, *consts), in_flat)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/lax/control_flow/common.py:77, in _initial_style_jaxpr_attrs(fun, in_tree, in_avals, debug_info)
#      73 def _initial_style_jaxpr_attrs(fun: Callable,
#      74                                in_tree: PyTreeDef,
#      75                                in_avals: Sequence[core.AbstractValue],
#      76                                debug_info: core.DebugInfo):
# ---> 77   jaxpr, consts, out_tree, attrs_tracked = _initial_style_open_jaxpr(
#      78       fun, in_tree, in_avals, debug_info)
#      79   closed_jaxpr = pe.close_jaxpr(pe.convert_constvars_jaxpr(jaxpr))
#      80   return closed_jaxpr, consts, out_tree, attrs_tracked
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/lax/control_flow/common.py:59, in _initial_style_open_jaxpr(fun, in_tree, in_avals, debug_info)
#      51 @weakref_lru_cache
#      52 def _initial_style_open_jaxpr(fun: Callable,
#      53                               in_tree: PyTreeDef,
#      54                               in_avals: Sequence[core.AbstractValue],
#      55                               debug_info: core.DebugInfo):
#      56   wrapped_fun, out_tree = api_util.flatten_fun_nokwargs(
#      57       lu.wrap_init(fun, debug_info=debug_info),
#      58       in_tree)
# ---> 59   jaxpr, _, consts, attrs_tracked = pe.trace_to_jaxpr_dynamic(
#      60       wrapped_fun, in_avals)
#      61   return jaxpr, consts, out_tree(), attrs_tracked
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/profiler.py:334, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     331 @wraps(func)
#     332 def wrapper(*args, **kwargs):
#     333   with TraceAnnotation(name, **decorator_kwargs):
# --> 334     return func(*args, **kwargs)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:2223, in trace_to_jaxpr_dynamic(fun, in_avals, keep_inputs)
#    2221 try:
#    2222   with core.set_current_trace(trace):
# -> 2223     ans = fun.call_wrapped(*in_tracers)
#    2225   out_tracers = map(trace.to_jaxpr_tracer, ans)
#    2226   _check_no_returned_refs(fun.debug_info, out_tracers)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/linear_util.py:211, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     209 def call_wrapped(self, *args, **kwargs):
#     210   """Calls the transformed function"""
# --> 211   return self.f_transformed(*args, **kwargs)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/api_util.py:90, in flatten_fun_nokwargs(f, store, in_tree, *args_flat)
#      86 @lu.transformation_with_aux2
#      87 def flatten_fun_nokwargs(f: Callable, store: lu.Store,
#      88                          in_tree: PyTreeDef, *args_flat):
#      89   py_args = tree_unflatten(in_tree, args_flat)
# ---> 90   ans = f(*py_args)
#      91   ans, out_tree = tree_flatten(ans)
#      92   store.store(out_tree)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/linear_util.py:402, in _get_result_paths_thunk(_fun, _store, *args, **kwargs)
#     400 @transformation_with_aux2
#     401 def _get_result_paths_thunk(_fun: Callable, _store: Store, *args, **kwargs):
# --> 402   ans = _fun(*args, **kwargs)
#     403   result_paths = tuple(f"result{_clean_keystr_arg_names(path)}" for path, _ in generate_key_paths(ans))
#     404   if _store:
#     405     # In some instances a lu.WrappedFun is called multiple times, e.g.,
#     406     # the bwd function in a custom_vjp
#
# Cell In[33], line 99, in invert_with_adam_history.<locals>.scan_step(carry, i)
#      97 def scan_step(carry, i):
#      98     pts, st, hist = carry
# ---> 99     g = jax.grad(loss_fn)(pts)
#     100     updates, st = opt.update(g, st, pts)
#     101     pts = optax.apply_updates(pts, updates)
#
#     [... skipping hidden 1 frame]
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/api.py:437, in grad.<locals>.grad_f(*args, **kwargs)
#     434 @wraps(fun, docstr=docstr, argnums=argnums)
#     435 @api_boundary
#     436 def grad_f(*args, **kwargs):
# --> 437   _, g = value_and_grad_f(*args, **kwargs)
#     438   return g
#
#     [... skipping hidden 1 frame]
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/api.py:508, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     506   _check_input_dtype_grad(holomorphic, allow_int, leaf)
#     507 if not has_aux:
# --> 508   ans, vjp_py = _vjp(f_partial, *dyn_args)
#     509 else:
#     510   ans, vjp_py, aux = _vjp(
#     511       f_partial, *dyn_args, has_aux=True)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/api.py:2066, in _vjp(fun, has_aux, *primals)
#    2064 if not has_aux:
#    2065   flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 2066   out_primals, vjp = ad.vjp(flat_fun, primals_flat)
#    2067   out_tree = out_tree()
#    2068 else:
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:284, in vjp(traceable, primals, has_aux)
#     282 def vjp(traceable: lu.WrappedFun, primals, has_aux=False):
#     283   if not has_aux:
# --> 284     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     285   else:
#     286     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:269, in linearize(traceable, *primals, **kwargs)
#     267 _, in_tree = tree_flatten(((primals, primals), {}))
#     268 jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# --> 269 jaxpr, out_pvals, consts = pe.trace_to_jaxpr_nounits(jvpfun_flat, in_pvals)
#     270 out_primals_pvals, out_tangents_pvals = tree_unflatten(out_tree(), out_pvals)
#     271 if any(not out_primal_pval.is_known() for out_primal_pval in out_primals_pvals):
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/profiler.py:334, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     331 @wraps(func)
#     332 def wrapper(*args, **kwargs):
#     333   with TraceAnnotation(name, **decorator_kwargs):
# --> 334     return func(*args, **kwargs)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:602, in trace_to_jaxpr_nounits(fun, pvals, instantiate)
#     600 fun = trace_to_subjaxpr_nounits(fun, trace, instantiate, fun.debug_info)
#     601 with core.set_current_trace(trace):
# --> 602   jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     603   assert not env
#     604 del trace, fun
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/linear_util.py:211, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     209 def call_wrapped(self, *args, **kwargs):
#     210   """Calls the transformed function"""
# --> 211   return self.f_transformed(*args, **kwargs)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:616, in trace_to_subjaxpr_nounits(f, trace, instantiate, debug_info, in_pvals)
#     608 @lu.transformation2
#     609 def trace_to_subjaxpr_nounits(
#     610     f: Callable,
#    (...)
#     613     debug_info: core.DebugInfo,
#     614     in_pvals: Sequence[PartialVal]):
#     615   assert all(isinstance(pv, PartialVal) for pv in in_pvals), in_pvals
# --> 616   out_tracers, jaxpr, out_consts, env = _trace_to_subjaxpr_nounits(
#     617       f, trace, instantiate, in_pvals, debug_info)
#     618   out_pvals = [t.pval for t in out_tracers]
#     619   del out_tracers
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:649, in _trace_to_subjaxpr_nounits(f, trace, instantiate, in_pvals, debug_info)
#     647 in_args = merge_lists(in_knowns, in_tracers, in_consts)
#     648 with core.set_current_trace(trace):
# --> 649   ans = f(*in_args)
#     650 assert isinstance(ans, (list, tuple)), (
#     651     f"Got unexpected return type when tracing function to jaxpr: {ans}")
#     652 assert all(isinstance(x, core.Tracer) or core.valid_jaxtype(x) for x in ans), (
#     653     f"Got unexpected return type when tracing function to jaxpr: {ans}")
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/api_util.py:73, in flatten_fun(f, store, in_tree, *args_flat)
#      69 @lu.transformation_with_aux2
#      70 def flatten_fun(f: Callable, store: lu.Store,
#      71                 in_tree: PyTreeDef, *args_flat):
#      72   py_args, py_kwargs = tree_unflatten(in_tree, args_flat)
# ---> 73   ans = f(*py_args, **py_kwargs)
#      74   ans, out_tree = tree_flatten(ans)
#      75   store.store(out_tree)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:80, in jvpfun(f, instantiate, transform_stack, primals, tangents)
#      77 ctx = (source_info_util.transform_name_stack('jvp') if transform_stack
#      78        else contextlib.nullcontext())
#      79 with ctx:
# ---> 80   out_primals, out_tangents = f(tag, primals, tangents)
#      81 if type(instantiate) is bool:
#      82   instantiate = [instantiate] * len(out_tangents)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:133, in jvp_subtrace(f, tag, primals, tangents)
#     130   in_tracers = [maybe_jvp_tracer(trace, x, t)
#     131                 for x, t in zip(primals, tangents)]
#     132   with core.set_current_trace(trace):
# --> 133     ans = f(*in_tracers)
#     134   out = unzip2(map(trace.to_primal_tangent_pair, ans))
#     135 return out
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/api_util.py:90, in flatten_fun_nokwargs(f, store, in_tree, *args_flat)
#      86 @lu.transformation_with_aux2
#      87 def flatten_fun_nokwargs(f: Callable, store: lu.Store,
#      88                          in_tree: PyTreeDef, *args_flat):
#      89   py_args = tree_unflatten(in_tree, args_flat)
# ---> 90   ans = f(*py_args)
#      91   ans, out_tree = tree_flatten(ans)
#      92   store.store(out_tree)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/api_util.py:288, in _argnums_partial(_fun, _dyn_argnums, _fixed_args, *dyn_args, **kwargs)
#     286 args = [next(fixed_args_).val if x is sentinel else x for x in args]
#     287 assert next(fixed_args_, sentinel) is sentinel
# --> 288 return _fun(*args, **kwargs)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/linear_util.py:402, in _get_result_paths_thunk(_fun, _store, *args, **kwargs)
#     400 @transformation_with_aux2
#     401 def _get_result_paths_thunk(_fun: Callable, _store: Store, *args, **kwargs):
# --> 402   ans = _fun(*args, **kwargs)
#     403   result_paths = tuple(f"result{_clean_keystr_arg_names(path)}" for path, _ in generate_key_paths(ans))
#     404   if _store:
#     405     # In some instances a lu.WrappedFun is called multiple times, e.g.,
#     406     # the bwd function in a custom_vjp
#
# Cell In[33], line 95, in invert_with_adam_history.<locals>.loss_fn(x)
#      94 def loss_fn(x):
# ---> 95     pred_bs = bispectrum(sum_of_diracs(x, LMAX))
#      96     return jnp.mean(jnp.abs(true_bs - pred_bs))
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/src/spectra.py:34, in sum_of_diracs(vectors, lmax, values)
#      32 if values is None:
#      33     values = jnp.linalg.norm(vectors, axis=1)
# ---> 34 return e3nn.sum(e3nn.s2_dirac(vectors, lmax, p_val=1, p_arg=-1) * values[:, None], axis=0)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/e3nn_jax/_src/s2grid.py:772, in s2_dirac(position, lmax, p_val, p_arg)
#     693 r"""Spherical harmonics expansion of a Dirac delta on the sphere.
#     694
#     695 The integral of the Dirac delta is 1.
#    (...)
#     769         e3nn.sum(e3nn.s2_dirac(positions, 4, p_val=1, p_arg=-1) * weights[:, None], axis=0)
#     770 """
#     771 irreps = s2_irreps(lmax, p_val, p_arg)
# --> 772 coeffs = e3nn.spherical_harmonics(
#     773     irreps, position, normalize=True, normalization="integral"
#     774 )  # [dim]
#     775 return coeffs / jnp.sqrt(4 * jnp.pi)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/e3nn_jax/_src/spherical_harmonics/__init__.py:168, in spherical_harmonics(irreps_out, input, normalize, normalization, algorithm)
#     165     r2 = jnp.where(r2 == 0.0, 1.0, r2)
#     166     x = x / jnp.sqrt(r2)
# --> 168 sh = _jited_spherical_harmonics(
#     169     tuple(ir.l for _, ir in irreps_out), x, normalization, algorithm
#     170 )
#     171 sh = [
#     172     jnp.repeat(y[..., None, :], mul, -2) if mul != 1 else y[..., None, :]
#     173     for (mul, ir), y in zip(irreps_out, sh)
#     174 ]
#     175 return e3nn.from_chunks(irreps_out, sh, x.shape[:-1], x.dtype)
#
#     [... skipping hidden 1 frame]
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/pjit.py:340, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     335 if config.no_tracing.value:
#     336   raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     337                      "`jit`, but 'no_tracing' is set")
#     339 (outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked, executable,
# --> 340  pgle_profiler) = _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     342 maybe_fastpath_data = _get_fastpath_data(
#     343     executable, out_tree, args_flat, out_flat, attrs_tracked, jaxpr.effects,
#     344     jaxpr.consts, jit_info.abstracted_axes,
#     345     pgle_profiler)
#     347 return outs, maybe_fastpath_data, _need_to_rebuild_with_fdo(pgle_profiler)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/pjit.py:193, in _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     191   out_flat, compiled, profiler = _pjit_call_impl_python(*args_flat, **p.params)
#     192 else:
# --> 193   out_flat = pjit_p.bind(*args_flat, **p.params)
#     194   compiled = None
#     195   profiler = None
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/core.py:496, in Primitive.bind(self, *args, **params)
#     494 def bind(self, *args, **params):
#     495   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 496   return self._true_bind(*args, **params)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/core.py:512, in Primitive._true_bind(self, *args, **params)
#     510 trace_ctx.set_trace(eval_trace)
#     511 try:
# --> 512   return self.bind_with_trace(prev_trace, args, params)
#     513 finally:
#     514   trace_ctx.set_trace(prev_trace)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/core.py:517, in Primitive.bind_with_trace(self, trace, args, params)
#     516 def bind_with_trace(self, trace, args, params):
# --> 517   return trace.process_primitive(self, args, params)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:491, in JVPTrace.process_primitive(self, primitive, tracers, params)
#     489   raise NotImplementedError(msg)
#     490 with core.set_current_trace(self.parent_trace):
# --> 491   primal_out, tangent_out = jvp(primals_in, tangents_in, **params)
#     493 if primitive.multiple_results:
#     494   return [maybe_jvp_tracer(self, x, t) for x, t in zip(primal_out, tangent_out)]
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/pjit.py:2184, in _pjit_jvp(primals_in, tangents_in, jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, ctx_mesh, name, keep_unused, inline, compiler_options_kvs)
#    2179 def _pjit_jvp(primals_in, tangents_in,
#    2180               jaxpr, in_shardings, out_shardings, in_layouts, out_layouts,
#    2181               donated_invars, ctx_mesh, name, keep_unused, inline,
#    2182               compiler_options_kvs):
#    2183   is_nz_tangents_in = [type(t) is not ad.Zero for t in tangents_in]
# -> 2184   jaxpr_jvp, is_nz_tangents_out = ad.jvp_jaxpr(
#    2185       jaxpr, is_nz_tangents_in, instantiate=False)
#    2187   def _filter_zeros(is_nz_l, l):
#    2188     return (x for nz, x in zip(is_nz_l, l) if nz)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:1149, in jvp_jaxpr(jaxpr, nonzeros, instantiate)
#    1147 if type(instantiate) is bool:
#    1148   instantiate = (instantiate,) * len(jaxpr.out_avals)
# -> 1149 return _jvp_jaxpr(jaxpr, tuple(nonzeros), tuple(instantiate))
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:1161, in _jvp_jaxpr(jaxpr, nonzeros, instantiate)
#    1159 tangent_avals = [aval.to_tangent_aval() for aval, nz in zip(jaxpr.in_avals, nonzeros) if nz]
#    1160 avals_in = list(it.chain(jaxpr.in_avals, tangent_avals))
# -> 1161 jaxpr_out, avals_out, literals_out, () = pe.trace_to_jaxpr_dynamic(
#    1162     f_jvp, avals_in)
#    1163 return core.ClosedJaxpr(jaxpr_out, literals_out), out_nonzeros()
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/profiler.py:334, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     331 @wraps(func)
#     332 def wrapper(*args, **kwargs):
#     333   with TraceAnnotation(name, **decorator_kwargs):
# --> 334     return func(*args, **kwargs)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:2223, in trace_to_jaxpr_dynamic(fun, in_avals, keep_inputs)
#    2221 try:
#    2222   with core.set_current_trace(trace):
# -> 2223     ans = fun.call_wrapped(*in_tracers)
#    2225   out_tracers = map(trace.to_jaxpr_tracer, ans)
#    2226   _check_no_returned_refs(fun.debug_info, out_tracers)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/linear_util.py:211, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     209 def call_wrapped(self, *args, **kwargs):
#     210   """Calls the transformed function"""
# --> 211   return self.f_transformed(*args, **kwargs)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:1172, in f_jvp_traceable(f, store, nonzeros, *primals_and_nztangents)
#    1169 nonzero_tangents = iter(primals_and_nztangents[num_primals:])
#    1170 tangents = [next(nonzero_tangents) if nz else Zero.from_primal_value(p)
#    1171             for p, nz in zip(primals, nonzeros)]
# -> 1172 primals_out, tangents_out = f(primals, tangents)
#    1173 out_nonzeros = [type(t) is not Zero for t in tangents_out]
#    1174 nonzero_tangents_out = [t for t in tangents_out if type(t) is not Zero]
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:80, in jvpfun(f, instantiate, transform_stack, primals, tangents)
#      77 ctx = (source_info_util.transform_name_stack('jvp') if transform_stack
#      78        else contextlib.nullcontext())
#      79 with ctx:
# ---> 80   out_primals, out_tangents = f(tag, primals, tangents)
#      81 if type(instantiate) is bool:
#      82   instantiate = [instantiate] * len(out_tangents)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:133, in jvp_subtrace(f, tag, primals, tangents)
#     130   in_tracers = [maybe_jvp_tracer(trace, x, t)
#     131                 for x, t in zip(primals, tangents)]
#     132   with core.set_current_trace(trace):
# --> 133     ans = f(*in_tracers)
#     134   out = unzip2(map(trace.to_primal_tangent_pair, ans))
#     135 return out
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/core.py:276, in jaxpr_as_fun(closed_jaxpr, *args)
#     267 @curry
#     268 def jaxpr_as_fun(closed_jaxpr: ClosedJaxpr, *args):
#     269   # TODO(dougalm): remove this hack when we add contexts to jaxpr.
#    (...)
#     273   # context modifications. In the meantime, disabling the checks when we
#     274   # round-trip prevents those ops producing spurious errors.
#     275   with config.debug_nans(False):
# --> 276     return eval_jaxpr(closed_jaxpr.jaxpr, closed_jaxpr.consts, *args)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/core.py:582, in eval_jaxpr(jaxpr, consts, propagate_source_info, *args)
#     579 traceback = eqn.source_info.traceback if propagate_source_info else None
#     580 with source_info_util.user_context(
#     581     traceback, name_stack=name_stack), eqn.ctx.manager:
# --> 582   ans = eqn.primitive.bind(*subfuns, *map(read, eqn.invars), **bind_params)
#     583 if eqn.primitive.multiple_results:
#     584   foreach(write, eqn.outvars, ans)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/custom_derivatives.py:376, in CustomJVPCallPrimitive.bind(self, *args, **params)
#     375 def bind(self, *args, **params):
# --> 376   return self._true_bind(*args, **params)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/core.py:512, in Primitive._true_bind(self, *args, **params)
#     510 trace_ctx.set_trace(eval_trace)
#     511 try:
# --> 512   return self.bind_with_trace(prev_trace, args, params)
#     513 finally:
#     514   trace_ctx.set_trace(prev_trace)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/custom_derivatives.py:380, in CustomJVPCallPrimitive.bind_with_trace(self, trace, args, params)
#     378 def bind_with_trace(self, trace, args, params):
#     379   fun, jvp, tracers = args[0], args[1], args[2:]
# --> 380   return trace.process_custom_jvp_call(self, fun, jvp, tracers, **params)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:543, in JVPTrace.process_custom_jvp_call(self, prim, fun, f_jvp, tracers, symbolic_zeros)
#     541   else:
#     542     tangents_in = map(replace_internal_symbolic_zeros, tangents_in)
# --> 543   outs = f_jvp.call_wrapped(*(tuple(primals_in) + tuple(tangents_in)))
#     545 primals_out, tangents_out = split_list(outs, [len(outs) // 2])
#     546 tangents_out = map(replace_rule_output_symbolic_zeros, tangents_out)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/linear_util.py:211, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     209 def call_wrapped(self, *args, **kwargs):
#     210   """Calls the transformed function"""
# --> 211   return self.f_transformed(*args, **kwargs)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/custom_derivatives.py:401, in lift_jvp.<locals>.jvp(*xs)
#     399 primals, tangents = xs[num_consts:n], xs[n+num_consts:]
#     400 zeros = [type(t) is SymbolicZero for t in tangents]
# --> 401 jvp_jaxpr, jvp_consts, out_zeros = jvp_jaxpr_fun.call_wrapped(*zeros)
#     402 nonzero_tangents = [t for t in tangents if type(t) is not SymbolicZero]
#     403 out = core.eval_jaxpr(jvp_jaxpr, jvp_consts, *primals, *nonzero_tangents)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/linear_util.py:211, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     209 def call_wrapped(self, *args, **kwargs):
#     210   """Calls the transformed function"""
# --> 211   return self.f_transformed(*args, **kwargs)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:2189, in _memoize.<locals>.memoized(*args)
#    2187 if out is sentinel:
#    2188   with core.set_current_trace(None):
# -> 2189     out = cells[args] = fn(*args)
#    2190 return out
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:2077, in DynamicJaxprTrace.process_custom_jvp_call.<locals>.jvp_jaxpr_thunk(*in_zeros)
#    2075 jvp_, out_zeros = _jvp_jaxpr_zeros(jvp, in_zeros, tuple(zero_avals))
#    2076 in_avals_ = (*in_avals, *nz_tangent_avals)
# -> 2077 jaxpr, _, out_consts, () = trace_to_jaxpr_dynamic(jvp_, in_avals_)
#    2078 return jaxpr, out_consts, out_zeros()
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/profiler.py:334, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     331 @wraps(func)
#     332 def wrapper(*args, **kwargs):
#     333   with TraceAnnotation(name, **decorator_kwargs):
# --> 334     return func(*args, **kwargs)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:2223, in trace_to_jaxpr_dynamic(fun, in_avals, keep_inputs)
#    2221 try:
#    2222   with core.set_current_trace(trace):
# -> 2223     ans = fun.call_wrapped(*in_tracers)
#    2225   out_tracers = map(trace.to_jaxpr_tracer, ans)
#    2226   _check_no_returned_refs(fun.debug_info, out_tracers)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/linear_util.py:211, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     209 def call_wrapped(self, *args, **kwargs):
#     210   """Calls the transformed function"""
# --> 211   return self.f_transformed(*args, **kwargs)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:2198, in _jvp_jaxpr_zeros(f, store, in_zeros, zero_avals, *primal_tangent_avals)
#    2196 symbolic_zeros = map(ad_util.SymbolicZero, zero_avals)
#    2197 tangents = merge_lists(in_zeros, nz_in_tangents, symbolic_zeros)
# -> 2198 out = f(*in_primals, *tangents)
#    2199 n, ragged = divmod(len(out), 2)
#    2200 assert not ragged
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/custom_derivatives.py:298, in _flatten_jvp(f, store, primal_name, jvp_name, in_tree, maybe_out_type, *args)
#     296 py_primals = tree_unflatten(in_tree, primals_in)
#     297 py_tangents = tree_unflatten(in_tree, tangents_in)
# --> 298 pair_out = f(py_primals, py_tangents)
#     299 if not isinstance(pair_out, (list, tuple)) or len(pair_out) != 2:
#     300   msg = (f"Custom JVP rule {jvp_name} for function {primal_name} "
#     301          "must produce a pair (list or tuple of length two) representing "
#     302          f"primal and tangent outputs, but got {pair_out}.")
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/api_util.py:234, in _prepend_static_args(f, static_args, *args, **kwargs)
#     232 static_args = tuple(arg.val for arg in static_args)
#     233 all_args = static_args + args
# --> 234 return f(*all_args, **kwargs)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/linear_util.py:402, in _get_result_paths_thunk(_fun, _store, *args, **kwargs)
#     400 @transformation_with_aux2
#     401 def _get_result_paths_thunk(_fun: Callable, _store: Store, *args, **kwargs):
# --> 402   ans = _fun(*args, **kwargs)
#     403   result_paths = tuple(f"result{_clean_keystr_arg_names(path)}" for path, _ in generate_key_paths(ans))
#     404   if _store:
#     405     # In some instances a lu.WrappedFun is called multiple times, e.g.,
#     406     # the bwd function in a custom_vjp
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/e3nn_jax/_src/spherical_harmonics/__init__.py:221, in _jvp(ls, normalization, algorithm, primals, tangents)
#     218 (x_dot,) = tangents
#     220 js = tuple(max(0, l - 1) for l in ls)
# --> 221 output = _custom_jvp_spherical_harmonics(ls + js, x, normalization, algorithm)
#     222 primal, res = output[: len(ls)], output[len(ls) :]
#     224 def h(l: int, r: jax.Array) -> jax.Array:
#
#     [... skipping hidden 1 frame]
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/custom_derivatives.py:288, in custom_jvp.__call__(self, *args, **kwargs)
#     285 flat_fun, out_type1 = _flatten_fun_nokwargs(f_, in_tree)
#     286 flat_jvp, out_type2 = _flatten_jvp(jvp, primal_name, debug_jvp.func_name,
#     287                                    in_tree, out_type1)
# --> 288 out_flat = custom_jvp_call_p.bind(flat_fun, flat_jvp, *args_flat,
#     289                                   symbolic_zeros=self.symbolic_zeros)
#     290 _, (out_tree, _) = lu.merge_linear_aux(out_type1, out_type2)
#     291 return tree_unflatten(out_tree, out_flat)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/custom_derivatives.py:376, in CustomJVPCallPrimitive.bind(self, *args, **params)
#     375 def bind(self, *args, **params):
# --> 376   return self._true_bind(*args, **params)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/core.py:512, in Primitive._true_bind(self, *args, **params)
#     510 trace_ctx.set_trace(eval_trace)
#     511 try:
# --> 512   return self.bind_with_trace(prev_trace, args, params)
#     513 finally:
#     514   trace_ctx.set_trace(prev_trace)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/custom_derivatives.py:380, in CustomJVPCallPrimitive.bind_with_trace(self, trace, args, params)
#     378 def bind_with_trace(self, trace, args, params):
#     379   fun, jvp, tracers = args[0], args[1], args[2:]
# --> 380   return trace.process_custom_jvp_call(self, fun, jvp, tracers, **params)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:2068, in DynamicJaxprTrace.process_custom_jvp_call(self, prim, fun, jvp, tracers, symbolic_zeros)
#    2066 in_avals = [t.aval for t in tracers]
#    2067 in_tangent_avals = [t.to_tangent_aval() for t in in_avals]
# -> 2068 fun_jaxpr, out_avals, consts, () = trace_to_jaxpr_dynamic(fun, in_avals)
#    2069 closed_fun_jaxpr = core.ClosedJaxpr(convert_constvars_jaxpr(fun_jaxpr), ())
#    2071 @_memoize
#    2072 def jvp_jaxpr_thunk(*in_zeros):
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/profiler.py:334, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     331 @wraps(func)
#     332 def wrapper(*args, **kwargs):
#     333   with TraceAnnotation(name, **decorator_kwargs):
# --> 334     return func(*args, **kwargs)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:2223, in trace_to_jaxpr_dynamic(fun, in_avals, keep_inputs)
#    2221 try:
#    2222   with core.set_current_trace(trace):
# -> 2223     ans = fun.call_wrapped(*in_tracers)
#    2225   out_tracers = map(trace.to_jaxpr_tracer, ans)
#    2226   _check_no_returned_refs(fun.debug_info, out_tracers)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/linear_util.py:211, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     209 def call_wrapped(self, *args, **kwargs):
#     210   """Calls the transformed function"""
# --> 211   return self.f_transformed(*args, **kwargs)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/custom_derivatives.py:87, in _flatten_fun_nokwargs(f, store, in_tree, *args_flat)
#      82 @lu.transformation_with_aux2
#      83 def _flatten_fun_nokwargs(f: Callable,
#      84                           store: lu.Store, in_tree: PyTreeDef,
#      85                           *args_flat):
#      86   py_args = tree_unflatten(in_tree, args_flat)
# ---> 87   ans = f(*py_args)
#      88   ans_flat, ans_tree = tree_flatten(ans)
#      89   ans_avals = [core.get_aval(x) for x in ans_flat]
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/api_util.py:288, in _argnums_partial(_fun, _dyn_argnums, _fixed_args, *dyn_args, **kwargs)
#     286 args = [next(fixed_args_).val if x is sentinel else x for x in args]
#     287 assert next(fixed_args_, sentinel) is sentinel
# --> 288 return _fun(*args, **kwargs)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/jax/_src/linear_util.py:402, in _get_result_paths_thunk(_fun, _store, *args, **kwargs)
#     400 @transformation_with_aux2
#     401 def _get_result_paths_thunk(_fun: Callable, _store: Store, *args, **kwargs):
# --> 402   ans = _fun(*args, **kwargs)
#     403   result_paths = tuple(f"result{_clean_keystr_arg_names(path)}" for path, _ in generate_key_paths(ans))
#     404   if _store:
#     405     # In some instances a lu.WrappedFun is called multiple times, e.g.,
#     406     # the bwd function in a custom_vjp
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/e3nn_jax/_src/spherical_harmonics/__init__.py:206, in _custom_jvp_spherical_harmonics(ls, x, normalization, algorithm)
#     202 @partial(jax.custom_jvp, nondiff_argnums=(0, 2, 3))
#     203 def _custom_jvp_spherical_harmonics(
#     204     ls: Tuple[int, ...], x: jax.Array, normalization: str, algorithm: Tuple[str]
#     205 ) -> List[jax.Array]:
# --> 206     return _spherical_harmonics(ls, x, normalization, algorithm)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/e3nn_jax/_src/spherical_harmonics/__init__.py:197, in _spherical_harmonics(ls, x, normalization, algorithm)
#     195     context = dict()
#     196     for l in ls:
# --> 197         recursive_spherical_harmonics(l, context, x, normalization, algorithm)
#     198     return [context[l] for l in ls]
#     199 raise ValueError("Unknown algorithm: must be 'legendre' or 'recursive'")
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/e3nn_jax/_src/spherical_harmonics/recursive.py:54, in recursive_spherical_harmonics(l, context, input, normalization, algorithm)
#      51 l2 = biggest_power_of_two(l - 1)
#      52 l1 = l - l2
# ---> 54 C_var = sqrtQarray_to_sympy(e3nn.clebsch_gordan(l1, l2, l))
#      55 yl_var = sympy.Array(
#      56     [
#      57         sum(
#    (...)
#      63     ]
#      64 )
#      66 yl1_var = recursive_spherical_harmonics(
#      67     l1, context, input, normalization, algorithm
#      68 )
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/e3nn_jax/_src/utils/sympy.py:21, in sqrtQarray_to_sympy(x)
#      19     return sqrtQ_to_sympy(x)
#      20 else:
# ---> 21     return sympy.Array([sqrtQarray_to_sympy(row) for row in x])
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/sympy/tensor/array/dense_ndim_array.py:134, in ImmutableDenseNDimArray.__new__(cls, iterable, shape, **kwargs)
#     133 def __new__(cls, iterable, shape=None, **kwargs):
# --> 134     return cls._new(iterable, shape, **kwargs)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/sympy/tensor/array/dense_ndim_array.py:138, in ImmutableDenseNDimArray._new(cls, iterable, shape, **kwargs)
#     136 @classmethod
#     137 def _new(cls, iterable, shape, **kwargs):
# --> 138     shape, flat_list = cls._handle_ndarray_creation_inputs(iterable, shape, **kwargs)
#     139     shape = Tuple(*map(_sympify, shape))
#     140     cls._check_special_bounds(flat_list, shape)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/sympy/tensor/array/ndim_array.py:234, in NDimArray._handle_ndarray_creation_inputs(cls, iterable, shape, **kwargs)
#     232 # Construct N-dim array from an iterable (numpy arrays included):
#     233 elif isinstance(iterable, Iterable):
# --> 234     iterable, shape = cls._scan_iterable_shape(iterable)
#     236 # Construct N-dim array from a Matrix:
#     237 elif isinstance(iterable, MatrixBase):
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/sympy/tensor/array/ndim_array.py:213, in NDimArray._scan_iterable_shape(cls, iterable)
#     210         result.extend(i)
#     211     return result, (len(shapes),)+shapes[0]
# --> 213 return f(iterable)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/sympy/tensor/array/ndim_array.py:206, in NDimArray._scan_iterable_shape.<locals>.f(pointer)
#     203     return [], (0,)
#     205 result = []
# --> 206 elems, shapes = zip(*[f(i) for i in pointer])
#     207 if len(set(shapes)) != 1:
#     208     raise ValueError("could not determine shape unambiguously")
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/sympy/tensor/array/ndim_array.py:206, in <listcomp>(.0)
#     203     return [], (0,)
#     205 result = []
# --> 206 elems, shapes = zip(*[f(i) for i in pointer])
#     207 if len(set(shapes)) != 1:
#     208     raise ValueError("could not determine shape unambiguously")
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/sympy/tensor/array/ndim_array.py:206, in NDimArray._scan_iterable_shape.<locals>.f(pointer)
#     203     return [], (0,)
#     205 result = []
# --> 206 elems, shapes = zip(*[f(i) for i in pointer])
#     207 if len(set(shapes)) != 1:
#     208     raise ValueError("could not determine shape unambiguously")
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/sympy/tensor/array/ndim_array.py:206, in <listcomp>(.0)
#     203     return [], (0,)
#     205 result = []
# --> 206 elems, shapes = zip(*[f(i) for i in pointer])
#     207 if len(set(shapes)) != 1:
#     208     raise ValueError("could not determine shape unambiguously")
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/sympy/tensor/array/ndim_array.py:485, in NDimArray.__iter__.<locals>.iterator()
#     483 if self._shape:
#     484     for i in range(self._shape[0]):
# --> 485         yield self[i]
#     486 else:
#     487     yield self[()]
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/sympy/tensor/array/dense_ndim_array.py:65, in DenseNDimArray.__getitem__(self, index)
#      63 if isinstance(index, tuple) and any(isinstance(i, slice) for i in index):
#      64     sl_factors, eindices = self._get_slice_data_for_array_access(index)
# ---> 65     array = [self._array[self._parse_index(i)] for i in eindices]
#      66     nshape = [len(el) for i, el in enumerate(sl_factors) if isinstance(index[i], slice)]
#      67     return type(self)(array, nshape)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/sympy/tensor/array/dense_ndim_array.py:65, in <listcomp>(.0)
#      63 if isinstance(index, tuple) and any(isinstance(i, slice) for i in index):
#      64     sl_factors, eindices = self._get_slice_data_for_array_access(index)
# ---> 65     array = [self._array[self._parse_index(i)] for i in eindices]
#      66     nshape = [len(el) for i, el in enumerate(sl_factors) if isinstance(index[i], slice)]
#      67     return type(self)(array, nshape)
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/sympy/tensor/array/ndim_array.py:168, in NDimArray._parse_index(self, index)
#     166     if index[i] < 0:
#     167         real_index += 1
# --> 168     real_index = real_index*self.shape[i] + index[i]
#     170 return real_index
#
# File ~/MIT Dropbox/Tuong Phung/repos/pyspectra/.venv/lib/python3.10/site-packages/sympy/core/numbers.py:1909, in Integer.__rmul__(self, other)
#    1907 def __rmul__(self, other):
#    1908     if global_parameters.evaluate:
# -> 1909         if isinstance(other, int):
#    1910             return Integer(other*self.p)
#    1911         elif isinstance(other, Rational):
#
# KeyboardInterrupt:

# %%
num_envs = 100

with open('../data/qm9_local_envs_10000.pkl','rb') as f:
    envs = pickle.load(f)

# Load and display saved results
output_file = f"../results/mae_{num_envs}_envs.pkl"

try:
    with open(output_file, "rb") as f:
        results = pickle.load(f)
    print(f"Loaded results from {output_file}")
except FileNotFoundError:
    print(f"Results file not found: {output_file}")
except Exception as e:
    print(f"Error loading results: {str(e)}")

# Plot all MAE values on the same plot
fig, ax = plt.subplots(figsize=(10, 8))

# Check if results contain the necessary data
if 'all_mae_values' not in results:
    print("Error: 'all_mae_values' not found in results dictionary")
else:
    # Use a colormap with more distinct colors
    import matplotlib.colors as mcolors
    # Combine multiple colormaps to get more distinct colors
    # Use a set of highly distinguishable colors that are clearly visible on white background
    colors = ['#000000', '#FF0000', '#0000FF', '#008000', '#FF00FF', '#800000', 
              '#000080', '#008080', '#800080', '#FF8000', '#00FF00', '#0080FF',
              '#FF0080', '#800080', '#FF8080', '#8000FF', '#00FF80', '#80FF00',
              '#FF00FF', '#000000']  # High contrast colors, starting with black, red, blue, green
    
    # Plot each environment's MAE values with different colors
    # Only plot every 50 iterations to reduce noise, but always include the last point
    step = 50
    for i in range(len(results['all_mae_values'])):
        mae_values = results['all_mae_values'][i]
        
        # Get indices for every step-th point
        indices = list(range(0, len(mae_values), step))
        
        # Make sure the last point is included
        if (len(mae_values) - 1) not in indices:
            indices.append(len(mae_values) - 1)
        
        # Get x and y values for plotting
        x_values = indices
        y_values = [mae_values[j] for j in indices]
        
        line = ax.plot(x_values, y_values, marker='o', linestyle='-', 
                alpha=0.5, color=colors[i % len(colors)])
        
        # Annotate curves with final MAE > 0.01
        if mae_values[-1] > 0:
            # Get number of neighbors for this environment
            num_neighbors = len(envs[i])
            
            # Add annotation at the end of the curve
            ax.annotate(f'Env {i} ({num_neighbors} neighbors)', 
                        xy=(len(mae_values)-1, mae_values[-1]),
                        xytext=(10, 0),
                        textcoords='offset points',
                        fontsize=9,
                        fontweight='bold',
                        color=colors[i % len(colors)])
    
    ax.set_title('MAE Values for Multiple Environments')
    ax.set_xlabel('Position')
    ax.set_ylabel('MAE Value')
    ax.set_ylim(0, 0.02)
    ax.grid(True)
    
    # Set integer x-axis ticks
    ax.xaxis.set_major_locator(plt.MaxNLocator(integer=True))
    
    plt.tight_layout()
    plt.show()
# Out:
# Loaded results from ../results/mae_100_envs.pkl

# %%
# Compute average MAE at the last iteration for environments with MAE < 0.03
# last_iteration_maes = [mae_values[-1] for mae_values in results['all_mae_values']]
# good_maes = [mae for mae in last_iteration_maes if mae < 0.03]
# average_last_mae = np.mean(good_maes) if good_maes else 0
# print(f"Average MAE at the last iteration (for MAE < 0.03): {average_last_mae:.6f}")
# print(f"Number of environments with MAE < 0.03: {len(good_maes)} out of {len(last_iteration_maes)}")

last_iteration_maes = [mae_values[-1] for mae_values in results['all_mae_values']]
print(f"Average MAE at the last iteration: {np.mean(last_iteration_maes):.6f}")

# 1 start = 0.005057, 0.54 s/env
# 5 start = 0.004040, 1.25 s/env
# 10 start = 0.003247, 1.33 s/env
# 20 start = 0.003451, 1.50 s/env

# 10 start, 0.004805
# 10 start with l-bfgs,
# Out:
# Average MAE at the last iteration: 0.009700
